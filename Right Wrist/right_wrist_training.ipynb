# %% [markdown]
# # Right wrist training

# %% [markdown]
# ## Acceleration

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('acc_data (right_wrist).csv')

X = np.column_stack((np.array(df['Acc_X']), np.array(df['Acc_Y']), np.array(df['Acc_Z'])))
y = np.array(df['PacketCounter']).reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#print(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.40, random_state = 42)
#print(X)

# %%
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y.ravel())
# Out:
# SVR()

# %%
ypred = regressor.predict(X)
print(ypred)
# Out:
# [ 2.34555114e-02 -1.46204708e+00 -1.50620507e+00 -1.57161990e+00
#  -1.59351008e+00 -1.58289027e+00 -1.54596122e+00 -1.55847586e+00
#  -1.54409155e+00 -1.45524744e+00 -1.35985298e+00 -1.21119086e+00
#  -1.17431121e+00 -1.32388094e+00 -1.36228529e+00 -1.40091944e+00
#  -1.37771587e+00 -1.23553451e+00 -1.14759951e+00 -1.09082720e+00
#  -9.93622678e-01 -8.76516701e-01 -8.15376426e-01 -6.88567491e-01
#  -6.43379037e-01 -8.17937636e-01 -9.81179478e-01 -1.02026780e+00
#  -9.30904344e-01 -9.19481874e-01 -1.06787291e+00 -1.20846787e+00
#  -1.13111210e+00 -1.00305546e+00 -8.52577902e-01 -7.09520407e-01
#  -6.01441287e-01 -3.73425840e-01 -4.99635724e-02  2.96684621e-01
#   5.15096541e-01  6.22544491e-01  7.36704978e-01  7.25913813e-01
#   6.56354898e-01  5.82955044e-01  3.92922157e-01  2.78435498e-01
#   7.46686233e-03 -2.33874347e-01 -5.25985460e-01 -6.64553787e-01
#  -8.15776633e-01 -8.29226403e-01 -8.29370394e-01 -7.68232050e-01
# ...

# %% [markdown]
# ### Acc_X

# %%
df_new = pd.DataFrame()
df_new['Acc_X'] = df['Acc_X']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Acceleration X', fontsize = 25)
plt.legend(prop={'size': 10})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %% [markdown]
# ### Acc_Y

# %%
df_new = pd.DataFrame()
df_new['Acc_Y'] = df['Acc_Y']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Acceleration Y', fontsize = 25)
plt.legend(prop={'size': 10})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %% [markdown]
# ### Acc_Z

# %%
df_new = pd.DataFrame()
df_new['Acc_Z'] = df['Acc_Z']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Acceleration Z', fontsize = 25)
plt.legend(prop={'size': 10})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %%
df_new = pd.DataFrame()
df_new['Acc_X'] = df['Acc_X']
df_new['Acc_Y'] = df['Acc_Y']
df_new['Acc_Z'] = df['Acc_Z']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Acceleration', fontsize = 25)
plt.legend(prop={'size': 10})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %%
df_new = pd.DataFrame()
df_new['Acc_X'] = df['Acc_X']
df_new['Acc_Y'] = df['Acc_Y']
df_new['Acc_Z'] = df['Acc_Z']
df_new['Predicted'] = ypred

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Acceleration', fontsize = 25)
plt.legend(prop={'size': 10})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %% [markdown]
# #### Baseline

# %%
#Baseline
from sklearn.dummy import DummyRegressor
dummy = DummyRegressor(strategy="mean")
dummy.fit(X, y)
y_dummypred = dummy.predict(X)

# %%
df_new = pd.DataFrame()
df_new['Acc_X'] = df['Acc_X']
df_new['Acc_Y'] = df['Acc_Y']
df_new['Acc_Z'] = df['Acc_Z']
df_new['Baseline'] = y_dummypred
df_new['Predicted'] = ypred


fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Acceleration', fontsize = 25)
plt.legend(prop={'size': 15})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %% [markdown]
# # Gyr

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('gyr_data (right_wrist).csv')

X = np.column_stack((np.array(df['Gyr_X']), np.array(df['Gyr_Y']), np.array(df['Gyr_Z'])))
y = np.array(df['PacketCounter']).reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#print(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.40, random_state = 42)
#print(X)

# %%
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y.ravel())
# Out:
# SVR()

# %%
ypred = regressor.predict(X)
print(ypred)
# Out:
# [ 0.38419     0.53917533  0.37865085  0.21335621  0.11486304 -0.00218008
#  -0.1016373  -0.14015946 -0.1400932  -0.14249941 -0.1237614  -0.05595153
#   0.05019648  0.13594796  0.15438989  0.13147238  0.10328701  0.07958505
#   0.11198985  0.14792748  0.16486761  0.16210268  0.13779891  0.13245629
#   0.15938052  0.16152272  0.09227369 -0.03957703 -0.14586634 -0.19436001
#  -0.17283387 -0.11814078 -0.05499483  0.04007443  0.1884785   0.3627669
#   0.50093545  0.5587309   0.58776477  0.61143447  0.63529927  0.64798625
#   0.65108287  0.64137372  0.61692981  0.57175496  0.51559508  0.4312535
#   0.34631685  0.24029788  0.14168861  0.05663631  0.00885425 -0.00197657
#   0.03747326  0.12533649  0.25294848  0.37419405  0.46782929  0.52257997
#   0.55167579  0.56833588  0.57054713  0.55093306  0.53212176  0.50759883
#   0.46787971  0.42334753  0.38500287  0.37025494  0.38236461  0.41600874
#   0.46337162  0.50292339  0.53568435  0.56229044  0.57952865  0.57864391
# ...

# %% [markdown]
# ### Gyr_X

# %%
df_new = pd.DataFrame()
df_new['Gyr_X'] = df['Gyr_X']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Gyr X', fontsize = 25)
plt.legend(prop={'size': 10})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %% [markdown]
# ### Gyr_Y

# %%
df_new = pd.DataFrame()
df_new['Gyr_Y'] = df['Gyr_Y']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Gyr Y', fontsize = 25)
plt.legend(prop={'size': 10})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %% [markdown]
# ### Gyr_Z

# %%
df_new = pd.DataFrame()
df_new['Gyr_Z'] = df['Gyr_Z']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Gyr Z', fontsize = 25)
plt.legend(prop={'size': 10})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %%
df_new = pd.DataFrame()
df_new['Gyr_X'] = df['Gyr_X']
df_new['Gyr_Y'] = df['Gyr_Y']
df_new['Gyr_Z'] = df['Gyr_Z']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Gyr', fontsize = 25)
plt.legend(prop={'size': 10})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %%
df_new = pd.DataFrame()
df_new['Gyr_X'] = df['Gyr_X']
df_new['Gyr_Y'] = df['Gyr_Y']
df_new['Gyr_Z'] = df['Gyr_Z']
df_new['Predicted'] = ypred

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Gyr', fontsize = 25)
plt.legend(prop={'size': 10})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %% [markdown]
# #### Baseline

# %%
#Baseline
from sklearn.dummy import DummyRegressor
dummy = DummyRegressor(strategy="mean")
dummy.fit(X, y)
y_dummypred = dummy.predict(X)

# %%
df_new = pd.DataFrame()
df_new['Gyr_X'] = df['Gyr_X']
df_new['Gyr_Y'] = df['Gyr_Y']
df_new['Gyr_Z'] = df['Gyr_Z']
df_new['Baseline'] = y_dummypred
df_new['Predicted'] = ypred

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Gyr', fontsize = 25)
plt.legend(prop={'size': 15})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %% [markdown]
# # Euler

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('euler_data (right_wrist).csv')

X = np.column_stack((np.array(df['Euler_X']), np.array(df['Euler_Y']), np.array(df['Euler_Z'])))
y = np.array(df['PacketCounter']).reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#print(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.40, random_state = 42)
#print(X)

# %%
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y.ravel())
# Out:
# SVR()

# %%
ypred = regressor.predict(X)
print(ypred)
# Out:
# [-1.58789515 -1.59820978 -1.60615571 -1.60323374 -1.59314238 -1.57267198
#  -1.54005735 -1.49821022 -1.4520877  -1.39945452 -1.33978088 -1.27559273
#  -1.20960464 -1.14721283 -1.08960167 -1.03672754 -0.9935903  -0.95844414
#  -0.93302168 -0.91522887 -0.90175763 -0.88920549 -0.8746621  -0.8573199
#  -0.83700621 -0.81496338 -0.78723313 -0.74994147 -0.70438488 -0.65271841
#  -0.60263508 -0.56268937 -0.53787866 -0.53171018 -0.5501882  -0.59587298
#  -0.66573716 -0.75034631 -0.8418072  -0.93302778 -1.01910433 -1.09610438
#  -1.16340475 -1.21882108 -1.26296321 -1.29406637 -1.31353125 -1.3196091
#  -1.31510323 -1.30074621 -1.28007767 -1.25356246 -1.22466177 -1.19557917
#  -1.16885269 -1.14590745 -1.12879278 -1.11893269 -1.11740232 -1.12272925
#  -1.13277837 -1.14560229 -1.15928163 -1.17053576 -1.17950078 -1.1862417
#  -1.19003029 -1.19122176 -1.19078007 -1.18993154 -1.18960844 -1.18990861
#  -1.19078307 -1.1904092  -1.18845254 -1.18336994 -1.1746093  -1.16006768
# ...

# %% [markdown]
# ### Euler_X

# %%
df_new = pd.DataFrame()
df_new['Euler_X'] = df['Euler_X']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Euler X', fontsize = 25)
plt.legend(prop={'size': 15})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %% [markdown]
# ### Euler_Y

# %%
df_new = pd.DataFrame()
df_new['Euler_Y'] = df['Euler_Y']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Euler Y', fontsize = 25)
plt.legend(prop={'size': 15})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %% [markdown]
# ### Euler_Z

# %%
df_new = pd.DataFrame()
df_new['Euler_Z'] = df['Euler_Z']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Euler Z', fontsize = 25)
plt.legend(prop={'size': 15})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %%
df_new = pd.DataFrame()
df_new['Euler_X'] = df['Euler_X']
df_new['Euler_Y'] = df['Euler_Y']
df_new['Euler_Z'] = df['Euler_Z']

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Euler', fontsize = 25)
plt.legend(prop={'size': 15})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %%
df_new = pd.DataFrame()
df_new['Euler_X'] = df['Euler_X']
df_new['Euler_Y'] = df['Euler_Y']
df_new['Euler_Z'] = df['Euler_Z']
df_new['Predicted'] = ypred

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Euler', fontsize = 25)
plt.legend(prop={'size': 15})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()

# %% [markdown]
# #### Baseline

# %%
from sklearn.dummy import DummyRegressor
dummy = DummyRegressor(strategy="mean")
dummy.fit(X, y)
y_dummypred = dummy.predict(X)

# %%
df_new = pd.DataFrame()
df_new['Euler_X'] = df['Euler_X']
df_new['Euler_Y'] = df['Euler_Y']
df_new['Euler_Z'] = df['Euler_Z']
df_new['Baseline'] = y_dummypred
df_new['Predicted'] = ypred

fig = plt.figure(figsize=(10, 5))
sns.lineplot(data=df_new)
plt.title('Euler', fontsize = 25)
plt.legend(prop={'size': 15})
plt.xlabel('', fontsize = 25)
plt.tick_params(labelsize=25)
plt.show()
